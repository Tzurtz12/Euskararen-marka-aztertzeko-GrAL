# %% [markdown]
# # Logistic regression:
#
# Sentimenduen sailkapena:
# * Positiboa --> 0
# * Neutroa --> 1
# * Negatiboa --> 2

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
with open('Data/Forms/X_train.bin', 'rb') as f:
    X_train = np.load(f)
with open('Data/Forms/X_test.bin', 'rb') as f:
    X_test = np.load(f)
with open('Data/Forms/y_train.bin', 'rb') as f:
    y_train = np.load(f)
with open('Data/Forms/y_test.bin', 'rb') as f:
    y_test = np.load(f)
class Dataset:
    def __init__(self, X_train, X_test, y_train, y_test):
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test
data = Dataset(X_train, X_test, y_train, y_test)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 268
# 68

# %%
with open('Data/X_train.bin', 'rb') as f:
    X_train = np.load(f)
with open('Data/X_test.bin', 'rb') as f:
    X_test = np.load(f)
with open('Data/y_train.bin', 'rb') as f:
    y_train = np.load(f)
with open('Data/y_test.bin', 'rb') as f:
    y_test = np.load(f)
class Dataset:
    def __init__(self, X_train, X_test, y_train, y_test):
        self.X_train = X_train
        self.X_test = X_test
        self.y_train = y_train
        self.y_test = y_test
data = Dataset(X_train, X_test, y_train, y_test)

# %%
def score(data, model):
    y_pred = model.predict(data.X_test)
    return accuracy_score(data.y_test, y_pred)
    
@ignore_warnings(category=ConvergenceWarning)
def fit_score(data, model):
    model.fit(data.X_train, data.y_train)
    return score(data, model)

# %%
@ignore_warnings(category=ConvergenceWarning)
def search_hyperparameters(data, model, param_grid, cv=5, verbose=0):
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid,
                               cv=cv,scoring='accuracy',verbose=verbose
    )
    grid_search.fit(data.X_train,data.y_train)
    return grid_search

# %%
params = {'C': [1e-6, 1e-5, 1e-7], 'solver': ['lbfgs', 'newton-cg','liblinear']}
model = LogisticRegression(random_state=42)
grid_search = search_hyperparameters(data, model, params, verbose=2)
print(f'{grid_search.best_params_ = }')
print(f'{grid_search.best_score_ = }')
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  18.1s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  18.3s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  17.1s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  18.0s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  18.8s
# [CV] END ..........................C=1e-06, solver=newton-cg; total time=   2.1s
# [CV] END ..........................C=1e-06, solver=newton-cg; total time=   1.4s
# [CV] END ..........................C=1e-06, solver=newton-cg; total time=   1.5s
# [CV] END ..........................C=1e-06, solver=newton-cg; total time=   1.7s
# [CV] END ..........................C=1e-06, solver=newton-cg; total time=   1.3s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.4s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.4s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.4s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.4s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.3s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  18.1s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  18.5s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  19.1s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  17.3s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  18.4s
# [CV] END ..........................C=1e-05, solver=newton-cg; total time=   1.5s
# [CV] END ..........................C=1e-05, solver=newton-cg; total time=   1.4s
# [CV] END ..........................C=1e-05, solver=newton-cg; total time=   1.6s
# [CV] END ..........................C=1e-05, solver=newton-cg; total time=   1.5s
# [CV] END ..........................C=1e-05, solver=newton-cg; total time=   1.6s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   0.7s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   0.6s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   0.6s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   0.7s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   0.5s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  16.4s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  16.7s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  16.3s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  19.1s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  18.1s
# [CV] END ..........................C=1e-07, solver=newton-cg; total time=   1.2s
# [CV] END ..........................C=1e-07, solver=newton-cg; total time=   1.4s
# [CV] END ..........................C=1e-07, solver=newton-cg; total time=   1.2s
# [CV] END ..........................C=1e-07, solver=newton-cg; total time=   1.3s
# [CV] END ..........................C=1e-07, solver=newton-cg; total time=   1.0s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.3s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.2s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.2s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.2s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.2s
# grid_search.best_params_ = {'C': 1e-05, 'solver': 'liblinear'}
# grid_search.best_score_ = np.float64(0.8246680642907058)

# %%
model = LogisticRegression(random_state=42, C = 1e-5, solver = 'liblinear') # {'C': 1e-5, 'solver': 'liblinear'}
print(f'Accuracy: {fit_score(data, model)*100:.1f}%')
# Out:
# Accuracy: 86.8%

# %%
model = LogisticRegression(random_state=42) # {'C': 1e-5, 'solver': 'liblinear'}
print(f'Accuracy: {fit_score(data, model)*100:.1f}%')
# Out:
# Accuracy: 77.9%

# %% [markdown]
# ### gpt esaldiekin

# %%
params = {'C': [1e-6, 1e-5, 1e-7], 'solver': ['lbfgs', 'liblinear']}
model = LogisticRegression(random_state=42)
grid_search = search_hyperparameters(data, model, params, verbose=2)
print(f'{grid_search.best_params_ = }')
print(f'{grid_search.best_score_ = }')
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  21.8s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  19.3s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  17.2s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  24.8s
# [CV] END ..............................C=1e-06, solver=lbfgs; total time=  26.5s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   1.0s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   1.0s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   1.0s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   0.9s
# [CV] END ..........................C=1e-06, solver=liblinear; total time=   1.0s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  34.7s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  22.5s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  25.2s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  24.6s
# [CV] END ..............................C=1e-05, solver=lbfgs; total time=  24.8s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   1.5s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   1.5s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   1.7s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   1.8s
# [CV] END ..........................C=1e-05, solver=liblinear; total time=   1.7s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  25.2s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  25.6s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  25.8s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  25.9s
# [CV] END ..............................C=1e-07, solver=lbfgs; total time=  23.3s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.7s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.6s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.6s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.7s
# [CV] END ..........................C=1e-07, solver=liblinear; total time=   0.6s
# grid_search.best_params_ = {'C': 1e-05, 'solver': 'lbfgs'}
# grid_search.best_score_ = np.float64(0.8555087358684481)

# %%
model = LogisticRegression(random_state=42, C = 1e-5, solver = 'lbfgs') # {'C': 1e-5, 'solver': 'liblinear'}
print(f'Accuracy: {fit_score(data, model)*100:.1f}%')
# Out:
# Accuracy: 82.9%

# %%
model = LogisticRegression(random_state=42) # {'C': 1e-5, 'solver': 'liblinear'}
print(f'Accuracy: {fit_score(data, model)*100:.1f}%')
# Out:
# Accuracy: 85.7%

# %% [markdown]
# ### Chatgpt probak

# %%
with open('Data/GPT/positive_gpt.bin', 'rb') as f:
    positive = np.load(f)
with open('Data/GPT/neutral_gpt.bin', 'rb') as f:
    neutral = np.load(f)
with open('Data/GPT/negative_gpt.bin', 'rb') as f:
    negative = np.load(f)

# %%
def sailkapena(esaldi, model):
    pred = model.predict(esaldi.reshape(1, -1))
    match pred[0]:
        case 0.0:
            return("Positibo")
        case 1.0:
            return("Neutroa")
        case 2.0:
            return("Negatiboa")

# %%
def sentimentua(esaldi, model):
    return model.predict(esaldi.reshape(1, -1))

# %%
model = LogisticRegression(random_state=42, C = 1e-5, solver = 'liblinear')
model.fit(data.X_train, data.y_train)
# Out:
# LogisticRegression(C=1e-05, random_state=42, solver='liblinear')

# %%
esaldi = positive[0]
sailkapena(esaldi,model)
# Out:
# 'Positibo'
