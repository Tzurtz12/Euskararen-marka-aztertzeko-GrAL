# %% [markdown]
# # Using orai-nlp/Llama-eus-8B
#
# **references:**
#
# * https://huggingface.co/orai-nlp/Llama-eus-8B
# * https://huggingface.co/docs/transformers/llm_tutorial

# %%
from google.colab import drive
drive.mount('/content/drive')
import json
import numpy as np
import gc
# Out:
# Mounted at /content/drive

# %%
#!pip install transformers bitsandbytes>=0.39.0

# %%
from transformers import AutoModelForCausalLM

# %%
#model = AutoModelForCausalLM.from_pretrained("orai-nlp/Llama-eus-8B", device_map="auto", load_in_4bit=True)
model = AutoModelForCausalLM.from_pretrained("orai-nlp/Llama-eus-8B", device_map="auto")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/872 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/121 [00:00<?, ?B/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
from transformers import AutoTokenizer
from accelerate.test_utils.testing import get_backend

DEVICE, _, _ = get_backend() # automatically detects the underlying device type (CUDA, CPU, XPU, MPS, etc.)
print(DEVICE)
tokenizer = AutoTokenizer.from_pretrained("orai-nlp/Llama-eus-8B", padding_side="left")
model_inputs = tokenizer(["Kolore zerrenda bat: gorria, urdina"], return_tensors="pt").to(DEVICE)
# Out:
# cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
generated_ids = model.generate(**model_inputs)
tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# 'Kolore zerrenda bat: gorria, urdina, berdea, horia, beltza, zuria, arrosa, morea,'

# %% [markdown]
# ## Embeddings

# %%
import transformers
import torch

# There are important!
torch.backends.cuda.enable_mem_efficient_sdp(False)
torch.backends.cuda.enable_flash_sdp(False)

# %%
from transformers import AutoTokenizer, AutoModel
from accelerate.test_utils.testing import get_backend

DEVICE, _, _ = get_backend() # automatically detects the underlying device type (CUDA, CPU, XPU, MPS, etc.)
print(DEVICE)

tokenizer = AutoTokenizer.from_pretrained("orai-nlp/Llama-eus-8B")
model = AutoModel.from_pretrained("orai-nlp/Llama-eus-8B", torch_dtype=torch.bfloat16, device_map="auto")
# Out:
# cuda
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/449 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/872 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the cpu.

# %%
# input text
esaldi = "Pilotan Altuna III. atera da garaile, Iñaki Artola 22-19 garaitu ondoren. Bi gipuzkoarrek urte luzeetan ahaztuko ez dugun erakustaldia eman ziguten."


inputs = tokenizer(esaldi, return_tensors="pt")

  # text embedding
with torch.no_grad():
    embeddings = model(**inputs).last_hidden_state

X = embeddings.sum(axis=1).cpu().float().numpy()
print(X.shape)
with open('/content/drive/MyDrive/Colab Notebooks/altuna.bin', 'wb') as f:
    np.save(f,X)
# Out:
# (1, 4096)

# %%
# input text
esaldi = "Pilotan Altuna atera da garaile."

tokens = tokenizer.tokenize(esaldi)
print("Tokens:", tokens)
# Out:
# Tokens: ['P', 'ilot', 'an', 'ĠAlt', 'una', 'Ġa', 'tera', 'Ġda', 'Ġg', 'ara', 'ile', '.']

# %%
# input text
esaldi = "Hegoafrikan ardo ona egiten omen da Stellenbosch aldean. Lurmutur hiria, Pretoria, hiri handiak ere topa daitezke"


inputs = tokenizer(esaldi, return_tensors="pt")

  # text embedding
with torch.no_grad():
    embeddings = model(**inputs).last_hidden_state

X = embeddings.sum(axis=1).cpu().float().numpy()
print(X.shape)
with open('/content/drive/MyDrive/Colab Notebooks/hegoafrika.bin', 'wb') as f:
    np.save(f,X)
# Out:
# (1, 4096)

# %%
X = embeddings.cpu().float().numpy()
print(X.shape, inputs.data['input_ids'].shape)
print(X.sum(axis=1))
# Out:
# (1, 22, 4096) torch.Size([1, 22])
# [[-23.628555   -8.2438965  -4.425537  ...  15.032227   14.272949
#    -2.8916016]]

# %%
embeddings.sum(axis=1).cpu().float().numpy().shape
# Out:
# (1, 4096)

# %%
import os
print(os.getcwd())
for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content
# /content/.config/.last_opt_in_prompt.yaml
# /content/.config/gce
# /content/.config/.last_update_check.json
# /content/.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# /content/.config/config_sentinel
# /content/.config/default_configs.db
# /content/.config/active_config
# /content/.config/.last_survey_prompt.yaml
# /content/.config/configurations/config_default
# /content/.config/logs/2025.05.29/14.01.02.146440.log
# /content/.config/logs/2025.05.29/14.01.01.430943.log
# /content/.config/logs/2025.05.29/14.00.52.256341.log
# /content/.config/logs/2025.05.29/14.00.20.854017.log
# /content/.config/logs/2025.05.29/14.00.51.008524.log
# /content/.config/logs/2025.05.29/14.00.41.804176.log
# /content/drive/MyDrive/Apunteak.pdf
# /content/drive/MyDrive/Dokumentu izengabea.gdoc
# /content/drive/MyDrive/URTZI_FlashPres.pptx
# /content/drive/MyDrive/Urtzi_Jauregi_PLANTILLA ANEXOS MÁSTER UB-CSIC Urtzi.pdf
# /content/drive/MyDrive/delft.gdoc
# /content/drive/MyDrive/Delft article.gdoc
# /content/drive/MyDrive/Colab Notebooks/Copia de orai-nlp_Llama-eus-8B.ipynb
# /content/drive/MyDrive/Colab Notebooks/geografia.jsonl
# /content/drive/MyDrive/Colab Notebooks/other.jsonl
# /content/drive/MyDrive/Colab Notebooks/historia.jsonl
# /content/drive/MyDrive/Colab Notebooks/zientzia_teknologia.jsonl
# /content/drive/MyDrive/Colab Notebooks/kirola.jsonl
# /content/drive/MyDrive/Colab Notebooks/ekonomia.jsonl
# /content/drive/MyDrive/Colab Notebooks/gizartea.jsonl
# /content/drive/MyDrive/Colab Notebooks/politika.jsonl
# /content/drive/MyDrive/Climate now/Solar geoengineering.gdoc
# /content/drive/MyDrive/Climate now/Video script.gdoc
# /content/drive/MyDrive/HZB/211108_BESSY_Postervorlage_A0_quer.pptx
# /content/drive/MyDrive/HZB/211108_HZB_Postervorlage_A0_hoch.pptx
# /content/drive/MyDrive/HZB/211108_HZB_Postervorlage_A0_quer.pptx
# /content/drive/MyDrive/HZB/Couplers.pdf
# /content/drive/MyDrive/HZB/AD8349.pdf
# /content/drive/MyDrive/HZB/ZX60-2522M+.pdf
# /content/drive/MyDrive/HZB/ZX05-5-S+.pdf
# /content/drive/MyDrive/HZB/ZN4PD1-50+.pdf
# /content/drive/MyDrive/HZB/1690376944167.jpg
# /content/drive/MyDrive/HZB/Photo from urtzikrak
# /content/drive/MyDrive/HZB/cross.jpg
# /content/drive/MyDrive/HZB/setup (1).jpg
# /content/drive/MyDrive/HZB/sokra.jpg
# /content/drive/MyDrive/HZB/setup.jpg
# /content/drive/MyDrive/HZB/POSTER URTZI.pptx
# /content/drive/MyDrive/HZB/Wigner Crystal.pptx
# /content/drive/MyDrive/HZB/Documentation/CAS2023_RF_Hands_on_Experiments.pdf
# /content/drive/MyDrive/HZB/Documentation/RFmeasurementsCAS2023.pdf
# /content/drive/MyDrive/HZB/Documentation/CAS2023_Theory_wCover.pdf
# /content/drive/MyDrive/HZB/Documentation/RFmeasurementsCAS2023_onlyPart2.pdf
# /content/drive/MyDrive/HZB/Documentation/Basics of RF Electronics Dexter Lecture 2.pdf
# /content/drive/MyDrive/HZB/Documentation/llrf.pdf
# /content/drive/MyDrive/HZB/Documentation/thtu3_talk.pdf
# /content/drive/MyDrive/HZB/Documentation/p105.pdf
# /content/drive/MyDrive/HZB/Documentation/10.18429_JACoW-ERL2019-MOCOXBS04.pdf
# /content/drive/MyDrive/HZB/Documentation/Dokumentu izengabea.gdoc
# /content/drive/MyDrive/HZB/Documentation/prueba1.pdf
# /content/drive/MyDrive/HZB/Fotok/pabessy
# /content/drive/MyDrive/HZB/Fotok/neu.jpg
# /content/drive/MyDrive/HZB/Fotok/cruse
# /content/drive/MyDrive/HZB/Fotok/1691490889784.jpg
# /content/drive/MyDrive/HZB/Fotok/Blog Urtzi.gdoc
# /content/drive/MyDrive/HZB/Fotok/RF schematics.jpeg
# /content/drive/MyDrive/HZB/Fotok/Paraguay.jpeg
# /content/drive/MyDrive/HZB/Simulink/matlab_simulink_tutorial.pdf
# /content/drive/MyDrive/HZB/Poster/POSTER URTZI.pdf
# /content/drive/MyDrive/HZB/Poster/Speech flash.gdoc
# /content/drive/MyDrive/BCN MASTER/20230803115504.L12V76W.pdf
# /content/drive/MyDrive/BCN MASTER/Urtzi_aval.pdf
# /content/drive/MyDrive/BCN MASTER/urtzi_aval.pdf
# /content/drive/MyDrive/BCN MASTER/Anexo_II_Informe_alumno_es_kopia.pdf
# /content/drive/MyDrive/BCN MASTER/Anexo_II_Informe_alumno_es.docx_kopia.pdf
# /content/drive/MyDrive/BCN MASTER/IMG_20240429_145239.jpg
# /content/drive/MyDrive/BCN MASTER/Screenshot_2024-04-29-14-54-05-555_com.ombiel.campusm.barcelona.jpg
# /content/drive/MyDrive/BCN MASTER/AQM/Essay_marking_scheme_AQM_9d33ee38c658ee0c080f5a6cda5d246e.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Aharanov,Bohm-Significance of Electromagnetic Potentials in the Quantum Theory_81e96760c7aa1a11a3524d36575bb566.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Aspect,Grangier,Roger-Experimental Realization of Einstein-Podolsky-Rosen-Bohm Gedankenexperiment- A New Violation of Bells Inequalities_91f672dfe26232b9a68479f611a45232.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Bell-On the Einstein-Podolsky-Rosen paradox_9d82cdf42d693909476ac62210392930.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Berry-Quantal phase factors accompanyonh adiabatic changes_39924d7c4919ecfac86a3eff38904b33.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Bohr-ON THE QUANTUM THEORY OF LINE–SPECTRA_815c2275ec05cdc5489096e8178f69fe.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Born,Heisenberg,Jordan-On quantum mechanics II_520a2f887e24b56375c02b2bd5b8686f.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Born,Jordan-On quantum mechanics_bd0bfa2dcfcbf8f311efe5229c9884f0.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/deBroglie-RADIATION — Waves and Quanta1_cc16da4eb492ef33f600f1f5a4cf6829.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Dirac-The Fundamental Equations of Quantum Mechanics_98945f323ffdc530458237b360e14f65.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Driac-On the theory of quantum mechanics_611e6f2c1094f0ccbb2dde224c84c23c.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Einstein,Podolsky,Rosen-Can Quantum-Mechanical Description of Physical Reality Be Considered Complete_82d7c9d53ba2128c16484b5f0b097998.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Fermi-On the Quantization of Perfect Monatomic Gases_3d8a123cd0f7c7f3edafd5cc153e66f5.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Feynman-Space Time approach to non-relativistic quantum mechanics_a1c944f3cc591ece33a253c5ad6898c5.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Glauber-Photon correlations_1606aca4b2735ac13d938652e308e683.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Heisenberg-Quantum theoretical reinterpretation of_721c2d02fdc4d98580d4111fa6e00d13.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Pauli-On the spectrum of hydrogen atom_1eac162423b5a3cdede940765882d7a8.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Planck-On the Law of the Energy Distribution in the Normal Spectrum_cd7f27a1d2feef1b386a7615053f67cd.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Robertson-The Uncertainty Principle_8af8a729283684506b3ff84cc291dd9a.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Sakai-Spin correlations of strongly interacting protons as test of Bells inequality_f9bc5591dbb7f09c0d3ed6cd79424146.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Schrodinger-Matrix and wave mechanics_864f56b74293588115cafc58a47f90b5.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Schrodinger-Quantisation_I_bed49860201539352e7f507eef3bbbaa.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Schrodinger-Quantisation_II_5e2a015d76c747c1e56825f9c7f6f0b1.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Schroedinger-An Undulatory Theory of the Mechanics of Atoms and Molecules _c262b54b129a08ac6ddb21ec8f5fa9ca.pdf
# /content/drive/MyDrive/BCN MASTER/AQM/Papers/Wooters,Zurek-A single quantum cannot be cloned_cd5e06fc1b23c0daad0a46c437eddc29.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/Lecture1_Einstein model -Notes_b83d6876d738df3425e71a6361f16e5a.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/Lecture2_Debye model - Notes_49e893892c30680759d0f7d59b02684c.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/Lecture3_ 1D Monoatomic chain- phonons Notes_80f050929282f94b10ee4f1c7597740f.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/Lecture3and4_Phonons_Extra_Notes_e11c5e178747c642ccd4833a13c2f035.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/Lecture4_Many atoms per unit cell - Notes_0dc68b991ba6fdb83384fa69d5a0b0c4.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/LectureNotes2012_by Professor Steven H. Simon_f23c6732fb4fe95a2b23f2814e9fc7af.pdf
# /content/drive/MyDrive/BCN MASTER/Condensed/Theory/DOC-20231026-WA0033._kopia
# /content/drive/MyDrive/BCN MASTER/TFM/QTECH_Alberto_ProcessFlow.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/1719775324995.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/1719959161242.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/1719959996569.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/1719775279497.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/TFM pres.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/2103.03853v2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/1723046634148.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/DOC-20240719-WA0002..pdf
# /content/drive/MyDrive/BCN MASTER/TFM/Tebbenjohanns et al. - 2021 - Quantum control of a nanoparticle optically levita.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino - Shortcut.lnk
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino-builder.exe
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino_debug.l4j.ini
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/msvcp100.dll
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/revisions.txt
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino.exe
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/wrapper-manifest.xml
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino.l4j.ini
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/libusb0.dll
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/msvcr100.dll
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino_debug.exe
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino.inf
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino.cat
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino-org.cat
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/AdafruitCircuitPlayground.cat
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino-org.inf
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/AdafruitCircuitPlayground.inf
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino_gemma.cat
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino_gemma.inf
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/dpinst-amd64.exe
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/dpinst-x86.exe
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/firstsketch_osci.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/testhextovolt.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/Electronics-master.zip
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/talkADC.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/firstsketch.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/firstsketch_osci_v0p2.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/basic_talk.py
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/ADC-DAC_ver_mat/ADC-DAC_ver_mat.ino
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/ADC-DAC/ADC-DAC.ino
# /content/drive/MyDrive/BCN MASTER/TFM/UB/AD7734_AD5764/AD7734_AD5764/ADC-DAC_ver_mat_2/ADC-DAC_ver_mat_2.ino
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/Normativa_LABSISAE v2.0_Urtzi.docx
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/1714653758939.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/Urtzi 0502.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/Urtzi 0509.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/IMG_20240429_142045.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/IMG_20240429_150737.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/IMG_20240429_150818.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/IMB-CNM/IMG_20240429_142000.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/note.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/wirebonding.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/Test board/1 Diodo.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/firma.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/ubr.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/web.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/LAn/cern.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/cv/ehu.svg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/cv/upv.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/cv/ub.jpg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/cv/oulu.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/cv/Curriculum Urtzi.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/Argazkiak/Camera Roll/desktop.ini
# /content/drive/MyDrive/BCN MASTER/TFM/pend/urtzi/Captures/desktop.ini
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/TFMtemplate-26-6-2023.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Urtzi pres.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Tests.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test board/1 Diodo.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/TFMtemplate-26-6-2023/diag2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/TFMtemplate-26-6-2023/setstack.sty
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/TFMtemplate-26-6-2023/MasterThesis2.tex
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/TFMtemplate-26-6-2023/quantumarticle.cls
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/TFMtemplate-26-6-2023/biblio.bib
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/3.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/5.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/keysight.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Copia de Tests.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/English _ 2013-06-30 _ PDF 1.71 MB B1540-90020 c20130521 [98].pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/9018-50233.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Tests 0304.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/fuente offset.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/08904-90007.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/1N4001.PDF
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/nooff100ms.bmp
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Normativa_LABSISAE v2.0_Urtzi.docx
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Test reunion sp/SETUP_ongi.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Test reunion sp/Copia de Tests 0304.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Test reunion sp/Copia de Tests 0304.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/noOff.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/noOff5s.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/100mspeaks.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/1speaks.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/500mspeaks.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/diode.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/diode100msdelay.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/I_V Sweep [(13) ; 4_23_2024 4_48_56 PM].txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/sweep100ms.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/plot.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/HPmeasurements.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/HP7.4e-5mbar.bmp
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/HP7.4e-5mbar.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/HP7.4e-5mbar.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/N5181A16uV2.5e-5mbar.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/N5181A16uV2.5e-5mbar.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/N5181A25uV2.5e-5mbar.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/N5181A25uV2.5e-5mbar.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/N5181A.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/N5181A.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/N5181A2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/N5181A2.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/hp.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/hp.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/sdaDiode.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/sdaDiode.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/Characteristics.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/0424.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/sda1nalanpunt.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/SDA/Baja presión/Test 50uV/sda1nalanpunt.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Reunion 0205/lock-in.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Reunion 0205/sda.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/wire bonding_MOSFET info.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/micromachines-14-00270.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/Irudik/SDA.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/Irudik/loc-in.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/Irudik/loc-in2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/Irudik/graphs.jpeg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/Sweep_Vds_Vg(0).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/Sweep_IdsandVgs.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/Sweep_Vds_Vg(0)b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/Sweep_Vds_Vg(0)c.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/Sweep_Vds_Vg(0)d.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/TEST NO VACUUM/VgSweep.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_G(10mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_G(100mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1b_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1b_G(10mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1b_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_G(100mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_G(100mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_G(10mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2b_SD(noise).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2b_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2b_SD.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2b_G(10mVSD)..png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/2b_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/1_G(100mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_G(10mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_G(100mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3_G(100mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/NoGate3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/NoGate3.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/Gate3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/Gate3.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_G(10mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_G(10mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_SD.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_G(100mVSD).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C6/SDA/3b_G(100mVSD).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1b_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1b_S.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_SDb.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_SDb.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1_G.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1b_SD(ok).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/1b_SD(ok).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2b_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2b_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2_G.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/2_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/3_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C5/SDA/3_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1_SD.bmp
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1b_SD_(VG=0.5).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/1b_SD(VG=0.5).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2_SD(VG=0).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2_SD(VG=0).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2b_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2b_G.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2b_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2_G.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/2_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/3_SD.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/3_SD.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/3_G.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/SDA/3_G.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/LOCKIN/1b_SD(Siemens).png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-30/W1C2/LOCKIN/1b_SD(Siemens).txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-29/Readme.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-29/Outside/1a.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-29/Outside/1a.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/1b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/1b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/1.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/1.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/2.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/2b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/2b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3_PLC.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/3_PLC.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/4.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/4.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/4b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/DS/4b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/1b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/1b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/1.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/1.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/2.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/2b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/2b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/3b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/3b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/4.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/4.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/4b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps B/Vgate/4b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Plots VS.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/1.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/1.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/1b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/2.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/2b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/2b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/3b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/3b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/3.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/4.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/4.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/4b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/Sweep gate/4b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/1.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/1.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/1b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/1biak.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/1biak.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/2.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/2b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/2b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/3b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/3b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/3.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/4.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/4.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/4b.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/4b.Txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/MOSFET/05-14/Disps A/sweep DS/Plots VS.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/LOCK-IN.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/set.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/SDA.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/SETUP.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/SETUP2.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/set ups with lock-in.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/SETUP3.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Test/Irudik/SETUP_ongi.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Potentials/potential shape electrostatic quantum dots.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Potentials/solution for the Hamiltonian in a QD.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/Design and fabrication of a SET for Quantum technologies.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/gate-defined quantum dots in intrinsicsilicon.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/sets.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/SEtS kastner 1992 revie wmodern physics.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/Single-hole tunneling through a two dimensional hole gas in intrinsic silicon.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/Bounouar2011.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/ncomms13575.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/SET/intel.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Punch through/66977-modeling-of-the-punch-through-effect-in-normally-on-sic-jfet-used-in-high-temperature-inverter-for-aerospace-application.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Punch through/Lec14.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/Physical_Model_of_Low-Temperature_to_Cryogenic_Thr.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/Silicon Single elctron transistor operating at room temperatire and theis Applications.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/51.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/cmos.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/essderc2002P05.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/takahashi1995.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/Single_electron_transistor_in_heterostructure_nano.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Temperature/12nmROOMT.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Silicon qubits/s41586-024-07275-6.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Silicon qubits/intel.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Notes about pics.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_00.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_01.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_02.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_03.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_04.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_05.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_06.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_07.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_08.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_09.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_10.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_11.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_12.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_13.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_14.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_15.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_16.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_17.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_18.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_19.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_20.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_21.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_22.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_23.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_24.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_25.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_26.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_27.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_28.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_29.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d3_30.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d4_31.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d5_32.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d5_33.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d5_34.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d5_35.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C10_MOSFET_d6_36.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_37.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_38.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_39.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_40.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_41.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_42.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d1_43.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d3_44.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d3_45.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d3_46.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d3_47.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d4_48.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d5_49.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d5_50.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d5_51.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d5_52.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C4_MOSFET_d6_53.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_54.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d1_55.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d1_56.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d1_57.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d1_58.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d2_59.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d3_60.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d3_61.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d3_62.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d4_63.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d4_64.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d5_65.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d5_66.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_d6_67.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_68.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_69.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_70.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_71.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_72.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_73.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_74.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_75.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_76.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_77.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_78.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_79.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_80.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_81.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/SEM/W8C6_MOSFET_PM_82.tif
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C9_5.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C9_6.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C9_6gate.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C10_1.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C10_6.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_1a.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_1b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_2drain.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_2gate.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_3.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_4.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_5Source.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_6a.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_6b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C7_6c.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_1Drain.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_3a.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_3b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_4a.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_4b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_5.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C8_6.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_1_Gate.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_3.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_3b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_5_Source.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_5.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C4_6.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_1.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_2.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_3_Source.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_3.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_3_b.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_4.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C5_5.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Mikroskopioa/Optiko/W8C6_4.JPG
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Meetings/Urtzi 0502.pptx
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Meetings/Urtzi 0502.pptx.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft1.asc
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft3.asc
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft2.log
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft2.raw
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft2.asc
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft3.log
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/Draft3.raw
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/diodobat.raw
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/diodobat.log
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/LTspice/diodobat.asc
# ...
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/block.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/signalchannel.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/refchannel.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/output filters.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/offsetmenu.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/equationmenu.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/oxcmenu.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Lock-In/Resumen/freqsweep.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Liburu.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Gailu.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Vivas gailu.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Vivas/1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Vivas/2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Vivas/3.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Vivas/4.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/DEO enero 2016.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/enero2020.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/DEO1819ene.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/GEO2122.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/GEO2122_ktrol_sc.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/GEO2122_ktrol_pn.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/GEO2122_ktrol_sc_atxiki.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/GEO2122_PN.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/Aurreko urteetako azterketak/WhatsApp Image 2023-01-11 at 15.44.24.jpeg
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/ari_mos.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/ari_mos_problemak.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/3.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/4.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/5.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/ari_mosfet_kalkulu.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/ari_mosfet_ez_id.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/5/ari_mosfet_problemak.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/bjt_adibide_1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/bjt_adibide2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/ari_bjt1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/ari_bjt2_problemak.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/3.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/4.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/Zeregin 2/Jauregi_Urtzi_zeregin2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/4/Zeregin 2/zuz.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_juntura.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_ek_ideal.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_adibide.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_juntura_ari.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_ari.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_ari_plus.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/pn_diodo_mugapen.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/schottky_konparaketa.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/Zeregina 1/pn_juntura_zeregin.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/Zeregina 1/Jauregi_Urtzi_zeregin1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/3/Zeregina 1/Zuzendua.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/1_sc_fis_oinarri.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Sc_adibide.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/param_eta_kte.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/ari_sc1.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/ari_sc2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Ariketak1-2.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Sc_azpimarra.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113/Si_mu_vs_N.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113/ni_vs_T.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113/mu_vs_T.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113/erresist.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Gailu/1/Zenbait baliabide-20221113/ezpurutasun_ionizazio_energia.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Coulomb blockade set/nanotechnology-understanding-small-systems.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Coulomb blockade set/blockade.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Coulomb blockade set/Tutorial_SET2003.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/IMB-CNM/Coulomb blockade set/lecture7-8-Mesophy.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/ADC-DAC.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/aa.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/my_devs.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/dummy.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/Main.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/database.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/exp.db
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Qcodes/__pycache__/my_devs.cpython-39.pyc
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/sweeps_v1.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/probak.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/sweep.txt.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/General_code_v1.ipynb
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/General_code_v1.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/My codes/ino_defecto/ino_defecto.ino
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Lock-in/SR830m.pdf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Lock-in/test_cases.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Lock-in/stanford_SR830_modified.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Lock-in/__pycache__/stanford_SR830_modified.cpython-39.pyc
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/Arduino/ADC-DAC_ver_mat_2/ADC-DAC_ver_mat_2.ino
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino - Shortcut.lnk
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/msvcr100.dll
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino_debug.l4j.ini
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/msvcp100.dll
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/libusb0.dll
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/revisions.txt
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino.l4j.ini
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino_debug.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/wrapper-manifest.xml
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/arduino-builder.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/AdafruitCircuitPlayground.cat
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino_gemma.inf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino.inf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/dpinst-amd64.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/AdafruitCircuitPlayground.inf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/dpinst-x86.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino-org.inf
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino_gemma.cat
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino.cat
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/arduino-1.8.9-windows/arduino-1.8.9/drivers/arduino-org.cat
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/firstsketch_osci.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/Electronics-master.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/testhextovolt.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/basic_talk.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/firstsketch.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/talkADC.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/firstsketch_osci_v0p2.py
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/ADC-DAC_ver_mat_2/ADC-DAC_ver_mat_2.ino
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/ADC-DAC_ver_mat/ADC-DAC_ver_mat.ino
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/AD7734_AD5764-20240507T104143Z-001/AD7734_AD5764/AD7734_AD5764/ADC-DAC/ADC-DAC.ino
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/GPIB/Keithley_GPIB488v92.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/GPIB/KI-488_v5.0.0_KI-488-5.0.0.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/GPIB/KI-488_v4.0.0_KI-488-4.0.0.zip
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/UB/GPIB/drivermax.exe
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/Memoria irudiak/electrochemical.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/Memoria irudiak/MOSFET.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/Memoria irudiak/SET.png
# /content/drive/MyDrive/BCN MASTER/TFM/pend/TFM/Memoria irudiak/circuitset.png
# /content/drive/MyDrive/BCN MASTER/TFM/presenta/TFM.pdf
# /content/drive/MyDrive/Sanboi/3 - -clausula-informativa-de-proteccion-de-datos_urtzi.pdf
# /content/drive/MyDrive/Sanboi/document-sepa-uesantboiana_urtzi.pdf
# /content/drive/MyDrive/Sanboi/1727104377567.jpg
# /content/drive/MyDrive/Sanboi/1727104377575.jpg
# /content/drive/MyDrive/Xiaomi/1714220255928.jpg
# /content/drive/MyDrive/Xiaomi/1714220579705.jpg
# /content/drive/MyDrive/Xiaomi/1714220579713.jpeg
# /content/drive/MyDrive/Xiaomi/6e73a7c251c2a9cd58c54cc9efeef3d1.mp4
# /content/drive/MyDrive/Lanak/Curriculum Urtzi.pdf
# /content/drive/MyDrive/Master unir/foto3.jpg
# /content/drive/MyDrive/Master unir/rot.jpg
# /content/drive/MyDrive/Master unir/TransferentziaBesteEntitateBateraEgiaztagiri1726088538832.pdf
# /content/drive/MyDrive/Master unir/Referenciado Alumno.gdoc
# /content/drive/MyDrive/Master unir/foto.jpg
# /content/drive/MyDrive/Master unir/foto2.jpg
# /content/drive/MyDrive/Master unir/Complementos/Infografía Urtzi Jauregi.docx
# /content/drive/MyDrive/Master unir/Complementos/comple-1-1_QP7qoQcj.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 8.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 7.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 6.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 5.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 4.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 3.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 2.m4a
# /content/drive/MyDrive/Master unir/Complementos/Comple 1.m4a
# /content/drive/MyDrive/Master unir/Complementos/Diseño sin título (2).mp4
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 1.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 2.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 3.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 4.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 5.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 6.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 7.m4a
# /content/drive/MyDrive/Master unir/Complementos/Edit/Comple 8.m4a
# /content/drive/MyDrive/Master unir/TFM/plantilla_program_didact.docx
# /content/drive/MyDrive/Sarrerak/bizardunak.pdf
# /content/drive/MyDrive/Sarrerak/bizardunak_gurasoak.pdf
# /content/drive/MyDrive/Sarrerak/sda.pdf
# /content/drive/MyDrive/Rugby M16/Plan de Juego Sub 16 2024-25 v2.0.pdf
# /content/drive/MyDrive/Enpresa eta proiektuak/Patenteak/Aurkezpena.gdoc
# /content/drive/MyDrive/Enpresa eta proiektuak/Komunikazioa/Zuhaitzak.gdoc
# /content/drive/MyDrive/Enpresa eta proiektuak/Proiektua/Aurkezpen.gdoc
# /content/sample_data/anscombe.json
# /content/sample_data/README.md
# /content/sample_data/california_housing_train.csv
# /content/sample_data/mnist_train_small.csv
# /content/sample_data/mnist_test.csv
# /content/sample_data/california_housing_test.csv

# %%
with open ("/content/drive/MyDrive/Colab Notebooks/gizartea_2.jsonl", "r") as file: #wikipedia
    gizartea = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/ekonomia_2.jsonl", "r") as file: #wikipedia
    ekonomia = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/geografia_2.jsonl", "r") as file: #wikipedia
    geografia = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/politika_2.jsonl", "r") as file: #wikipedia
    politika = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/kirola_2.jsonl", "r") as file: #wikipedia
    kirola = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/other_2.jsonl", "r") as file: #wikipedia
    other = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/zientzia_teknologia_2.jsonl", "r") as file: #wikipedia
    zientzia_teknologia = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/historia_2.jsonl", "r") as file: #wikipedia
    historia = json.load(file)

# %% [markdown]
# ### Geografia (48 / 66 esaldi)

# %%
# input text
embed_geografia = np.empty((0,4096))
excep_geografia = []
i= 0
for esaldi in geografia:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_geografia = np.vstack((embed_geografia,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_geografia.append(esaldi)
        torch.cuda.empty_cache()
        continue

  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_geografia.shape)
with open('/content/drive/MyDrive/Colab Notebooks/geografia.bin', 'wb') as f:
    np.save(f,embed_geografia)
# Out:
# (66, 4096)

# %%
with open('/content/drive/MyDrive/Colab Notebooks/geografia.bin', 'rb') as f:
    X = np.load(f)

# %% [markdown]
# ### Historia (118 / 102 esaldi)

# %%
# input text
embed_historia = np.empty((0,4096))
excep_historia = []
i = 0
for esaldi in historia:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_historia = np.vstack((embed_historia,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_historia.append(esaldi)
        torch.cuda.empty_cache()
        continue

  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_historia.shape)
with open('/content/drive/MyDrive/Colab Notebooks/historia.bin', 'wb') as f:
    np.save(f,embed_historia)
# Out:
# (102, 4096)

# %% [markdown]
# ### Zientzia eta teknologia (151 / 150 esaldi)

# %%
# input text
embed_zientzia = np.empty((0,4096))
excep_zientzia_teknologia = []
i = 0
for esaldi in zientzia_teknologia:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_zientzia = np.vstack((embed_zientzia,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_zientzia_teknologia.append(esaldi)
        torch.cuda.empty_cache()
        continue

  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_zientzia.shape)
with open('/content/drive/MyDrive/Colab Notebooks/zientzia_teknologia.bin', 'wb') as f:
    np.save(f,embed_zientzia)
# Out:
# (150, 4096)

# %% [markdown]
# ### Ekonomia (239 / 238 esaldi)

# %%
# input text
embed_ekonomia = np.empty((0,4096))
excep_ekonomia = []
i = 0
for esaldi in ekonomia:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_ekonomia = np.vstack((embed_ekonomia,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_ekonomia.append(esaldi)
        torch.cuda.empty_cache()
        continue

  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_ekonomia.shape)
with open('/content/drive/MyDrive/Colab Notebooks/ekonomia.bin', 'wb') as f:
    np.save(f,embed_ekonomia)
# Out:
# (238, 4096)

# %%
print(len(kirola))
print(len(kirola[:290]))
print(len(kirola[290:]))
# Out:
# 592
# 290
# 302

# %%
print(len(kirola[266].split()))
# Out:
# 857

# %% [markdown]
# ### Kirola (592 / 494 esaldi)

# %%
# input text
embed_kirola = np.empty((0,4096))
excep_kirol = []
i = 0
for esaldi in kirola:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_kirola = np.vstack((embed_kirola,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_kirol.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_kirola.shape)
with open('/content/drive/MyDrive/Colab Notebooks/kirola.bin', 'wb') as f:
    np.save(f,embed_kirola)
# Out:
# (494, 4096)

# %%
with open("/content/drive/MyDrive/Colab Notebooks/salbuespen_kirola.jsonl", "w") as f:
  json.dump(excep_kirol,f)

# %% [markdown]
# ### Politika (732 / 682  esaldi)

# %%
# input text
embed_politika = np.empty((0,4096))
excep_politika = []
i = 0
for esaldi in politika:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_politika = np.vstack((embed_politika,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_politika.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_politika.shape)
with open('/content/drive/MyDrive/Colab Notebooks/politika.bin', 'wb') as f:
    np.save(f,embed_politika)
with open("/content/drive/MyDrive/Colab Notebooks/salbuespen_politika.jsonl", "w") as f:
  json.dump(excep_politika,f)
# Out:
# (682, 4096)

# %% [markdown]
# ### Gizartea (1496 / 1528 esaldi)

# %%
# input text
embed_gizartea = np.empty((0,4096))
excep_gizartea = []
i = 0
for esaldi in gizartea:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_gizartea = np.vstack((embed_gizartea,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_gizartea.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_gizartea.shape)
with open('/content/drive/MyDrive/Colab Notebooks/gizartea.bin', 'wb') as f:
    np.save(f,embed_gizartea)
with open("/content/drive/MyDrive/Colab Notebooks/salbuespen_gizartea.jsonl", "w") as f:
  json.dump(excep_gizartea,f)
# Out:
# Out of memory 550.
# Out of memory 1314.
# (1526, 4096)

# %% [markdown]
# ### Sentiment Analysis

# %%
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/positive.jsonl", "r") as file: #positibo
    positive = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/negative.jsonl", "r") as file: #negatibo
    negative = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/neutral.jsonl", "r") as file: #neutroa
    neutral = json.load(file)

# %% [markdown]
# ### **Positibo** 130 esaldi

# %%
# input text
embed_positibo = np.empty((0,4096))
excep_positibo = []
i = 0
for esaldi in positive:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_positibo = np.vstack((embed_positibo,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_positibo.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_positibo.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/positive.bin', 'wb') as f:
    np.save(f,embed_positibo)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_positive.jsonl", "w") as f:
  json.dump(excep_positibo,f)
# Out:
# (130, 4096)

# %% [markdown]
# ### **Negatibo** 103 esaldi

# %%
# input text
embed_negatibo = np.empty((0,4096))
excep_negatibo = []
i = 0
for esaldi in negative:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_negatibo = np.vstack((embed_negatibo,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_positibo.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_negatibo.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/negative.bin', 'wb') as f:
    np.save(f,embed_negatibo)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_negative.jsonl", "w") as f:
  json.dump(excep_negatibo,f)
# Out:
# (103, 4096)

# %% [markdown]
# ### **Neutro** 103 esaldi

# %%
# input text
embed_neutro = np.empty((0,4096))
excep_neutro = []
i = 0
for esaldi in neutral:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_neutro = np.vstack((embed_neutro,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_neutro.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_neutro.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/neutral.bin', 'wb') as f:
    np.save(f,embed_neutro)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_neutral.jsonl", "w") as f:
  json.dump(excep_neutro,f)
# Out:
# (103, 4096)

# %% [markdown]
# ## **ChatGPT**-rekin eraikitako esaldiak

# %%
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/positive_gpt.jsonl", "r") as file: #positibo
    positive_gpt = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/negative_gpt.jsonl", "r") as file: #negatibo
    negative_gpt = json.load(file)
with open ("/content/drive/MyDrive/Colab Notebooks/sentiment/neutral_gpt.jsonl", "r") as file: #neutroa
    neutral_gpt = json.load(file)

# %% [markdown]
# ### **Positibo** 178 esaldi

# %%
# input text
embed_positibo = np.empty((0,4096))
excep_positibo = []
i = 0
for esaldi in positive_gpt:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_positibo = np.vstack((embed_positibo,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_positibo.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_positibo.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/positive_gpt.bin', 'wb') as f:
    np.save(f,embed_positibo)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_positive_gpt.jsonl", "w") as f:
  json.dump(excep_positibo,f)
# Out:
# (178, 4096)

# %% [markdown]
# ### **Negatibo** 180 esaldi

# %%
# input text
embed_positibo = np.empty((0,4096))
excep_positibo = []
i = 0
for esaldi in negative_gpt:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_positibo = np.vstack((embed_positibo,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_positibo.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_positibo.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/negative_gpt.bin', 'wb') as f:
    np.save(f,embed_positibo)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_negative_gpt.jsonl", "w") as f:
  json.dump(excep_positibo,f)
# Out:
# (180, 4096)

# %% [markdown]
# ### **Neutro** 180 esaldi

# %%
# input text
embed_positibo = np.empty((0,4096))
excep_positibo = []
i = 0
for esaldi in neutral_gpt:
  i +=1
  try:
    inputs = tokenizer(esaldi, return_tensors="pt")

    # text embedding
    with torch.no_grad():
        embeddings = model(**inputs).last_hidden_state

    X = embeddings.sum(axis=1).cpu().float().numpy()
    embed_positibo = np.vstack((embed_positibo,X))
  except torch.cuda.OutOfMemoryError:
        print(f"Out of memory {i-1}. ")
        excep_positibo.append(esaldi)
        torch.cuda.empty_cache()
        continue
  del inputs,embeddings, X
  torch.cuda.empty_cache()
  gc.collect()
print(embed_positibo.shape)
with open('/content/drive/MyDrive/Colab Notebooks/sentiment/neutral_gpt.bin', 'wb') as f:
    np.save(f,embed_positibo)
with open("/content/drive/MyDrive/Colab Notebooks/sentiment/salbuespen_neutral_gpt.jsonl", "w") as f:
  json.dump(excep_positibo,f)
# Out:
# (180, 4096)
